# %%
# %pip install plotly
# Out:
# ...
# [notice] A new release of pip is available: 23.0.1 -> 25.2
# [notice] To update, run: C:\Users\Ellie\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip
# ...

# %%
import pandas as pd
import numpy as np
import random
from sys import maxsize 
import matplotlib.cm as cm
import itertools
from collections import defaultdict
import matplotlib.pyplot as plt
from itertools import permutations
from scipy.sparse.csgraph import minimum_spanning_tree
from scipy.spatial import distance_matrix
import plotly.graph_objects as go

# %%
plt.rcParams['figure.figsize'] = (14,4)
plt.rcParams['axes.edgecolor'] = 'black'
plt.rcParams['axes.linewidth'] = 1.5
plt.rcParams['figure.frameon'] = True
plt.rcParams['axes.spines.top'] = False
plt.rcParams['axes.spines.right'] = False
plt.rcParams["font.family"] = "monospace";

# %%
import os
print(os.getcwd()) # get current working directory
# Out:
# d:\AI_teaching\AI_FMI_course\solved_problems\genetic_algorithms

# %% [markdown]
# This datasets are taken from kaggle:

# %%
tiny = pd.read_csv('dataset_TSP/tiny.csv', names=['A', 'B'], header=None)
small = pd.read_csv('dataset_TSP/small.csv', names=['A', 'B'], header=None)
medium = pd.read_csv('dataset_TSP/medium.csv', names=['A', 'B'], header=None)
large = pd.read_csv('dataset_TSP/large.csv', names=['A', 'B'], header=None)
